# %% [markdown]
# # 🔷 小学一年级奥数：图形认识
#
# ## 学习目标
# - 认识基本图形：圆形、正方形、三角形、长方形
# - 学习图形的特征和属性
# - 通过游戏和故事学习图形
# - 培养空间想象力

# %% [markdown]
# ## 1. 认识圆形
#
# 圆形是圆圆的，没有角！

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei', 'SimSun']
plt.rcParams['axes.unicode_minus'] = False

def draw_circle():
    """绘制圆形"""
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # 绘制圆形
    circle = plt.Circle((0, 0), 1, facecolor='lightblue', 
                       edgecolor='blue', linewidth=4)
    ax.add_patch(circle)
    
    # 标注
    ax.text(0, 0, '圆形', fontsize=20, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.3, '圆圆的，没有角', fontsize=14, ha='center', fontweight='bold')
    
    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-1.5, 1.5)
    ax.set_aspect('equal')
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# 显示圆形
print("🔵 认识圆形：")
print("圆形是圆圆的，没有角")
print("像太阳、月亮、车轮都是圆形")
draw_circle()
# Out:
# 🔵 认识圆形：
# 圆形是圆圆的，没有角
# 像太阳、月亮、车轮都是圆形

# %% [markdown]
# ## 2. 认识正方形
#
# 正方形有4条边，4个角，每条边都一样长！

# %%
def draw_square():
    """绘制正方形"""
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # 绘制正方形
    square = plt.Rectangle((-0.5, -0.5), 1, 1, facecolor='lightgreen', 
                          edgecolor='green', linewidth=4)
    ax.add_patch(square)
    
    # 标注角
    corners = [(-0.5, 0.5), (0.5, 0.5), (0.5, -0.5), (-0.5, -0.5)]
    for i, (x, y) in enumerate(corners):
        ax.text(x, y + 0.15, f'角{i+1}', fontsize=12, ha='center', fontweight='bold')
    
    # 标注边
    ax.text(0, 0.6, '边1', fontsize=12, ha='center', fontweight='bold')
    ax.text(0.6, 0, '边2', fontsize=12, ha='center', va='center', fontweight='bold')
    ax.text(0, -0.6, '边3', fontsize=12, ha='center', fontweight='bold')
    ax.text(-0.6, 0, '边4', fontsize=12, ha='center', va='center', fontweight='bold')
    
    # 标注
    ax.text(0, 0, '正方形', fontsize=20, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.3, '4条边，4个角，边边相等', fontsize=14, ha='center', fontweight='bold')
    
    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-1.5, 1.5)
    ax.set_aspect('equal')
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# 显示正方形
print("🟩 认识正方形：")
print("正方形有4条边，4个角")
print("每条边都一样长")
print("像方形的桌子、窗户都是正方形")
draw_square()
# Out:
# 🟩 认识正方形：
# 正方形有4条边，4个角
# 每条边都一样长
# 像方形的桌子、窗户都是正方形

# %% [markdown]
# ## 3. 认识三角形
#
# 三角形有3条边，3个角！

# %%
def draw_triangle():
    """绘制三角形"""
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # 绘制三角形
    triangle = plt.Polygon([(-0.5, -0.5), (0.5, -0.5), (0, 0.5)], 
                          facecolor='lightyellow', edgecolor='orange', linewidth=4)
    ax.add_patch(triangle)
    
    # 标注角
    ax.text(-0.5, -0.35, '角1', fontsize=12, ha='center', fontweight='bold')
    ax.text(0.5, -0.35, '角2', fontsize=12, ha='center', fontweight='bold')
    ax.text(0, 0.35, '角3', fontsize=12, ha='center', fontweight='bold')
    
    # 标注边
    ax.text(0, -0.65, '边1', fontsize=12, ha='center', fontweight='bold')
    ax.text(0.55, 0, '边2', fontsize=12, ha='center', va='center', fontweight='bold')
    ax.text(-0.55, 0, '边3', fontsize=12, ha='center', va='center', fontweight='bold')
    
    # 标注
    ax.text(0, 0, '三角形', fontsize=20, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.3, '3条边，3个角', fontsize=14, ha='center', fontweight='bold')
    
    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-1.5, 1.5)
    ax.set_aspect('equal')
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# 显示三角形
print("🔺 认识三角形：")
print("三角形有3条边，3个角")
print("像三明治、三角板都是三角形")
draw_triangle()
# Out:
# 🔺 认识三角形：
# 三角形有3条边，3个角
# 像三明治、三角板都是三角形

# %% [markdown]
# ## 4. 认识长方形
#
# 长方形有4条边，4个角，对边相等！

# %%
def draw_rectangle():
    """绘制长方形"""
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # 绘制长方形
    rectangle = plt.Rectangle((-0.75, -0.5), 1.5, 1, facecolor='lightpink', 
                             edgecolor='red', linewidth=4)
    ax.add_patch(rectangle)
    
    # 标注角
    corners = [(-0.75, 0.5), (0.75, 0.5), (0.75, -0.5), (-0.75, -0.5)]
    for i, (x, y) in enumerate(corners):
        ax.text(x, y + 0.15, f'角{i+1}', fontsize=12, ha='center', fontweight='bold')
    
    # 标注边
    ax.text(0, 0.6, '长边', fontsize=12, ha='center', fontweight='bold')
    ax.text(0, -0.6, '长边', fontsize=12, ha='center', fontweight='bold')
    ax.text(0.85, 0, '短边', fontsize=12, ha='center', va='center', fontweight='bold')
    ax.text(-0.85, 0, '短边', fontsize=12, ha='center', va='center', fontweight='bold')
    
    # 标注
    ax.text(0, 0, '长方形', fontsize=20, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.3, '4条边，4个角，对边相等', fontsize=14, ha='center', fontweight='bold')
    
    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-1.5, 1.5)
    ax.set_aspect('equal')
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# 显示长方形
print("🟥 认识长方形：")
print("长方形有4条边，4个角")
print("对边相等，邻边不等")
print("像书本、门都是长方形")
draw_rectangle()
# Out:
# 🟥 认识长方形：
# 长方形有4条边，4个角
# 对边相等，邻边不等
# 像书本、门都是长方形

# %% [markdown]
# ## 5. 图形对比
#
# 让我们对比一下这些图形！

# %%
def compare_shapes():
    """对比图形"""
    print("📊 图形对比")
    print("=" * 40)
    
    fig, axes = plt.subplots(2, 2, figsize=(12, 12))
    
    # 圆形
    ax = axes[0, 0]
    circle = plt.Circle((0, 0), 0.8, facecolor='lightblue', 
                       edgecolor='blue', linewidth=3)
    ax.add_patch(circle)
    ax.text(0, 0, '圆形', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '没有角', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    # 正方形
    ax = axes[0, 1]
    square = plt.Rectangle((-0.4, -0.4), 0.8, 0.8, facecolor='lightgreen', 
                          edgecolor='green', linewidth=3)
    ax.add_patch(square)
    ax.text(0, 0, '正方形', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '4条边，4个角', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    # 三角形
    ax = axes[1, 0]
    triangle = plt.Polygon([(-0.4, -0.4), (0.4, -0.4), (0, 0.4)], 
                          facecolor='lightyellow', edgecolor='orange', linewidth=3)
    ax.add_patch(triangle)
    ax.text(0, 0, '三角形', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '3条边，3个角', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    # 长方形
    ax = axes[1, 1]
    rectangle = plt.Rectangle((-0.6, -0.4), 1.2, 0.8, facecolor='lightpink', 
                             edgecolor='red', linewidth=3)
    ax.add_patch(rectangle)
    ax.text(0, 0, '长方形', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '4条边，4个角', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    plt.suptitle('基本图形对比', fontsize=18, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    # 图形特征表
    print("\n图形特征表：")
    print("-" * 40)
    print(f"{'图形':<10} {'边数':<8} {'角数':<8} {'特征':<15}")
    print("-" * 40)
    print(f"{'圆形':<10} {'无':<8} {'无':<8} {'圆圆的':<15}")
    print(f"{'正方形':<10} {'4':<8} {'4':<8} {'边边相等':<15}")
    print(f"{'三角形':<10} {'3':<8} {'3':<8} {'稳定':<15}")
    print(f"{'长方形':<10} {'4':<8} {'4':<8} {'对边相等':<15}")
    print("-" * 40)

# 运行图形对比
compare_shapes()

# %% [markdown]
# ## 6. 数学故事：图形王国
#
# 通过故事学习图形！

# %%
def shape_kingdom():
    """图形王国"""
    print("📖 图形王国")
    print("=" * 40)
    
    print("\n从前，有一个神奇的图形王国。")
    print("王国里住着四个好朋友：")
    print("\n1. 圆形圆圆 - 她是圆圆的，没有角，喜欢滚来滚去")
    print("2. 正方形方方 - 他有4条边，4个角，每条边都一样长")
    print("3. 三角形三三 - 他有3条边，3个角，最稳定")
    print("4. 长方形长长 - 他有4条边，4个角，对边相等")
    
    print("\n有一天，国王举办了一场图形大赛。")
    print("圆圆说：'我会滚，所以我是最快的！'")
    print("方方说：'我很稳，可以当桌子！'")
    print("三三说：'我很稳定，可以当屋顶！'")
    print("长长说：'我可以当书本，也可以当门！'")
    
    print("\n国王说：'你们都很棒！'")
    print("'圆形可以当车轮，滚得快！'")
    print("'正方形可以当桌子，很稳！'")
    print("'三角形可以当屋顶，很坚固！'")
    print("'长方形可以当书本和门，很有用！'")
    
    print("\n从此以后，四个好朋友一起快乐地生活。")
    print("他们互相帮助，一起建设美丽的图形王国！")
    
    # 可视化四个图形
    fig, axes = plt.subplots(2, 2, figsize=(12, 12))
    
    # 圆形圆圆
    ax = axes[0, 0]
    circle = plt.Circle((0, 0), 0.8, facecolor='lightblue', 
                       edgecolor='blue', linewidth=3)
    ax.add_patch(circle)
    ax.text(0, 0, '圆圆', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '圆形', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    # 正方形方方
    ax = axes[0, 1]
    square = plt.Rectangle((-0.4, -0.4), 0.8, 0.8, facecolor='lightgreen', 
                          edgecolor='green', linewidth=3)
    ax.add_patch(square)
    ax.text(0, 0, '方方', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '正方形', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    # 三角形三三
    ax = axes[1, 0]
    triangle = plt.Polygon([(-0.4, -0.4), (0.4, -0.4), (0, 0.4)], 
                          facecolor='lightyellow', edgecolor='orange', linewidth=3)
    ax.add_patch(triangle)
    ax.text(0, 0, '三三', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '三角形', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    # 长方形长长
    ax = axes[1, 1]
    rectangle = plt.Rectangle((-0.6, -0.4), 1.2, 0.8, facecolor='lightpink', 
                             edgecolor='red', linewidth=3)
    ax.add_patch(rectangle)
    ax.text(0, 0, '长长', fontsize=16, ha='center', va='center', fontweight='bold')
    ax.text(0, -1.1, '长方形', fontsize=12, ha='center', fontweight='bold')
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.axis('off')
    
    plt.suptitle('图形王国的四个好朋友', fontsize=18, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    # 思考题
    print("\n🤔 思考题：")
    print("1. 圆形圆圆可以当什么？")
    print("   答案：车轮、太阳、月亮")
    print("2. 正方形方方可以当什么？")
    print("   答案：桌子、窗户")
    print("3. 三角形三三可以当什么？")
    print("   答案：屋顶、三明治")
    print("4. 长方形长长可以当什么？")
    print("   答案：书本、门")

# 运行故事
shape_kingdom()
# Out:
# 📖 图形王国
# ...
#
# 从前，有一个神奇的图形王国。
# 王国里住着四个好朋友：
#
# 1. 圆形圆圆 - 她是圆圆的，没有角，喜欢滚来滚去
# 2. 正方形方方 - 他有4条边，4个角，每条边都一样长
# 3. 三角形三三 - 他有3条边，3个角，最稳定
# 4. 长方形长长 - 他有4条边，4个角，对边相等
#
# 有一天，国王举办了一场图形大赛。
# 圆圆说：'我会滚，所以我是最快的！'
# 方方说：'我很稳，可以当桌子！'
# 三三说：'我很稳定，可以当屋顶！'
# 长长说：'我可以当书本，也可以当门！'
#
# 国王说：'你们都很棒！'
# '圆形可以当车轮，滚得快！'
# '正方形可以当桌子，很稳！'
# '三角形可以当屋顶，很坚固！'
# '长方形可以当书本和门，很有用！'
#
# 从此以后，四个好朋友一起快乐地生活。
# 他们互相帮助，一起建设美丽的图形王国！
# 🤔 思考题：
# 1. 圆形圆圆可以当什么？
#    答案：车轮、太阳、月亮
# 2. 正方形方方可以当什么？
#    答案：桌子、窗户
# 3. 三角形三三可以当什么？
#    答案：屋顶、三明治
# 4. 长方形长长可以当什么？
#    答案：书本、门

# %% [markdown]
# ## 7. 找图形游戏
#
# 来玩找图形的游戏吧！

# %%
import random

def find_shape_game():
    """找图形游戏"""
    print("🎮 找图形游戏")
    print("=" * 40)
    print("规则：看图形，说出它的名字")
    
    score = 0
    total_questions = 5
    
    shapes = [
        {'name': '圆形', 'draw': lambda ax: ax.add_patch(plt.Circle((0, 0), 0.8, facecolor='lightblue', edgecolor='blue', linewidth=4))},
        {'name': '正方形', 'draw': lambda ax: ax.add_patch(plt.Rectangle((-0.4, -0.4), 0.8, 0.8, facecolor='lightgreen', edgecolor='green', linewidth=4))},
        {'name': '三角形', 'draw': lambda ax: ax.add_patch(plt.Polygon([(-0.4, -0.4), (0.4, -0.4), (0, 0.4)], facecolor='lightyellow', edgecolor='orange', linewidth=4))},
        {'name': '长方形', 'draw': lambda ax: ax.add_patch(plt.Rectangle((-0.6, -0.4), 1.2, 0.8, facecolor='lightpink', edgecolor='red', linewidth=4)))}
    ]
    
    for i in range(total_questions):
        print(f"\n问题 {i+1}/{total_questions}")
        
        # 随机选择一个图形
        shape = random.choice(shapes)
        
        # 绘制图形
        fig, ax = plt.subplots(figsize=(6, 6))
        shape['draw'](ax)
        ax.set_xlim(-1.2, 1.2)
        ax.set_ylim(-1.2, 1.2)
        ax.set_aspect('equal')
        ax.axis('off')
        plt.tight_layout()
        plt.show()
        
        # 询问答案
        answer = input("这是什么图形？")
        
        if answer == shape['name']:
            print("✅ 答对了！")
            score += 1
        else:
            print(f"❌ 不对哦，正确答案是 {shape['name']}")
    
    print(f"\n🎯 游戏结束！")
    print(f"你的得分：{score}/{total_questions}")
    
    if score == total_questions:
        print("🏆 太厉害了！全部正确！")
    elif score >= total_questions * 0.8:
        print("🌟 做得很好！继续保持！")
    else:
        print("💪 继续加油，多练习就会进步！")

# 运行游戏
find_shape_game()

# %% [markdown]
# ## 8. 图形计数
#
# 数一数有多少个图形！

# %%
def count_shapes():
    """图形计数"""
    
    import random
    
    print("🔢 图形计数")
    print("=" * 40)
    
    # 创建随机图形
    fig, ax = plt.subplots(figsize=(10, 10))
    
    # 生成随机图形
    shapes = []
    for _ in range(10):
        shape_type = random.choice(['circle', 'square', 'triangle', 'rectangle'])
        x = random.uniform(-3, 3)
        y = random.uniform(-3, 3)
        
        if shape_type == 'circle':
            circle = plt.Circle((x, y), 0.3, facecolor='lightblue', 
                               edgecolor='blue', linewidth=2)
            ax.add_patch(circle)
            shapes.append('圆形')
        elif shape_type == 'square':
            square = plt.Rectangle((x-0.25, y-0.25), 0.5, 0.5, facecolor='lightgreen', 
                                  edgecolor='green', linewidth=2)
            ax.add_patch(square)
            shapes.append('正方形')
        elif shape_type == 'triangle':
            triangle = plt.Polygon([(x-0.3, y-0.25), (x+0.3, y-0.25), (x, y+0.25)], 
                                  facecolor='lightyellow', edgecolor='orange', linewidth=2)
            ax.add_patch(triangle)
            shapes.append('三角形')
        elif shape_type == 'rectangle':
            rectangle = plt.Rectangle((x-0.4, y-0.25), 0.8, 0.5, facecolor='lightpink', 
                                     edgecolor='red', linewidth=2)
            ax.add_patch(rectangle)
            shapes.append('长方形')
    
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_aspect('equal')
    ax.axis('off')
    plt.suptitle('数一数有多少个图形', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    # 统计图形数量
    from collections import Counter
    shape_counts = Counter(shapes)
    
    print("\n图形统计：")
    print("-" * 30)
    for shape, count in shape_counts.items():
        print(f"{shape}: {count}个")
    print("-" * 30)
    print(f"总计: {len(shapes)}个")
    
    # 思考题
    print("\n🤔 思考题：")
    print(f"1. 最多的是什么图形？")
    most_common = shape_counts.most_common(1)[0]
    print(f"   答案：{most_common[0]}，有{most_common[1]}个")
    print(f"2. 最少的是什么图形？")
    least_common = shape_counts.most_common()[-1]
    print(f"   答案：{least_common[0]}，有{least_common[1]}个")

# 运行图形计数
count_shapes()
# Out:
# 🔢 图形计数
# ...
# 图形统计：
# ------------------------------
# 长方形: 1个
# 圆形: 2个
# 三角形: 5个
# 正方形: 2个
# ------------------------------
# 总计: 10个
#
# 🤔 思考题：
# 1. 最多的是什么图形？
#    答案：三角形，有5个
# 2. 最少的是什么图形？
#    答案：长方形，有1个

# %% [markdown]
# ## 🎉 总结
#
# 今天我们学习了：
#
# 1. ✅ 认识圆形 - 圆圆的，没有角
# 2. ✅ 认识正方形 - 4条边，4个角，边边相等
# 3. ✅ 认识三角形 - 3条边，3个角
# 4. ✅ 认识长方形 - 4条边，4个角，对边相等
# 5. ✅ 图形对比 - 对比不同图形的特征
# 6. ✅ 数学故事 - 图形王国
# 7. ✅ 找图形游戏 - 巩固图形认知
# 8. ✅ 图形计数 - 数图形的数量
#
# **小贴士**：
# - 圆形没有角，可以滚动
# - 正方形边边相等
# - 三角形最稳定
# - 长方形对边相等
# - 多观察生活中的图形
# - 下次我们学习更有趣的内容！
